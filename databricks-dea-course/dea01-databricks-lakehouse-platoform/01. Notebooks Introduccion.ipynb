# %% [markdown]
# # Introduction to Notebooks
# ## Heading - Python
# ## Heading - SQL
# - bullet 1
# - bullet 2
#
# This notebook introduces you to the concepts of notebooks at Databricks!

# %% [markdown]
# ## Python

# %%
print("Welcome")
print("Hello")

# %%
print("hello word")

# %% [markdown]
# ## SQL

# %%
# %sql
SELECT 'Hello from SQL'
