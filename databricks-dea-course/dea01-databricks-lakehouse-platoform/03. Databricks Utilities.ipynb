# %% [markdown]
# ### Databricks Utilities
# - Utilidades disponibles en Databricks
# - Acceder a la ayuda de una Utilidad
# - Utilizar una Utilidad en Databricks

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.help("cp")

# %%
# %fs
ls /databricks-datasets/

# %%
display(dbutils.fs.ls("/databricks-datasets/"))

# %%
for folder_name in dbutils.fs.ls("/databricks-datasets"):
    print(folder_name.path)
