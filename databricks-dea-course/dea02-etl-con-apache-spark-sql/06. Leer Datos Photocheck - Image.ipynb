-- %% [markdown]
-- ### Leer Datos IMAGE de la carpeta "Photochecks"
-- 1. Consultar los elementos de la carpeta "photochecks"
-- 2. Consultar archivos "photochecks" mediante el formato BinaryFile
-- 3. Crear la Vista(View) en el esquema "bronze"

-- %% [markdown]
-- #### 1. Consultar los elementos de la carpeta "photochecks"

-- %%
%fs ls '/Volumes/zenviro/raw/operational_data/photochecks/'

-- %% [markdown]
-- #### 2. Consultar archivos "photochecks" mediante el formato BinaryFile

-- %%
SELECT * FROM read_files('/Volumes/zenviro/raw/operational_data/photochecks/*/*.png',
                        format => 'binaryFile');

-- %% [markdown]
-- #### 3. Crear la Vista(View) en el esquema "bronze"

-- %%
CREATE OR REPLACE VIEW zenviro.bronze.v_photochecks
AS
SELECT * FROM read_files('/Volumes/zenviro/raw/operational_data/photochecks/*/*.png',
                        format => 'binaryFile');

-- %%
SELECT * FROM zenviro.bronze.v_photochecks;
